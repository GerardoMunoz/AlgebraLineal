# %% [markdown]
# # Rectas y Planos
#
# ## Rectas en 2D
#
# | $y=mx+b$ | $Ax+By=C$ |
# |-|-|
# | $m$: Pendiente | $A$:? |
# | $b$: punto de corte | $B$:? |
# | | $C$:? |
# | $m$ y $b$ únicos | $A,B,C$ no únicos|
# | No rectas verticales | Todas las rectas |
#
# En la siguiente tabla, las columnas describen algunas representaciones de las rectas en 2D. Los últimos tres renglones presentan como pasar de una representación a otra.
#
#
#
# | | I Ecuación lineal |  II Ecuación Paramétrica |  III Ecuación vectorial  | IV Dos puntos |
# |-|-|-|
# | | $Ax + By = C$     | $$\begin{matrix} x=P_x +t v_x \\ y=p_y +t v_y \end{matrix} $$ | $$\begin{bmatrix} x \\ y \end{bmatrix} = \begin{bmatrix} P_x \\ P_y \end{bmatrix} + t\begin{bmatrix} v_x \\ v_y \end{bmatrix}$$         | $$P,Q$$ |
# | De I | | Solución general de $\begin{bmatrix} A & B & : & C \end{bmatrix}$ | Solución general de $\begin{bmatrix} A & B & : & C \end{bmatrix}$ | |
# | De II o III | Despejar $t$ e igualar | Notación | Notación |  $ \begin{matrix}P = \begin{bmatrix} P_x \\ P_y \end{bmatrix}\\Q = \begin{bmatrix} P_x \\ P_y \end{bmatrix} + 1\begin{bmatrix} v_x \\ v_y \end{bmatrix}\end{matrix}$|
# | De IV | | | $\begin{bmatrix} P_x \\ P_y \end{bmatrix}=P$, $\begin{bmatrix} v_x \\ v_y \end{bmatrix}=Q-P$ | .|
#
# Ejercicio. Complete la tabla para que las ecuaciones del mismo renglón representen la misma recta. Dibuje por cada renglón: la recta, los puntos $P$ y $Q$ y los vectores $v$ y $\begin{bmatrix} A \\ B \end{bmatrix}$.
#
# | I Ecuación lineal |  II Ecuación Paramétrica |  III Ecuación vectorial  | IV Dos puntos |
# |-|-|-|-|
# |$2x+3y=6$| | | |
# | | |$\begin{bmatrix} x \\ y \end{bmatrix} = \begin{bmatrix} -3 \\ 1 \end{bmatrix} + t\begin{bmatrix} 2 \\ 1 \end{bmatrix}$| |
# | | | | $\begin{bmatrix} 2\\ 2 \end{bmatrix}, \begin{bmatrix} -1 \\ 1 \end{bmatrix}$|
#
# La siguiente tabla describe las representaciones de las rectas en 2D que pasan por el origen. En este caso para pasar de una representación a otra es suficiente con encontrar valores que cumplan $\begin{bmatrix} A \\ B \end{bmatrix} \cdot \begin{bmatrix} v_x \\ v_y \end{bmatrix}=0$
#
#
#
#  |  Ecuación lineal |   Ecuación Paramétrica |   Ecuación vectorial |  Otro punto | Ortogonal a
# |-|-|-|
#  | $$Ax + By = 0$$     | $$\begin{matrix} x=t v_x \\ y=t v_y \end{matrix} $$ | $$\begin{bmatrix} x \\ y \end{bmatrix} =  t\begin{bmatrix} v_x \\ v_y \end{bmatrix}$$         | $$\begin{bmatrix} v_x \\ v_y \end{bmatrix}$$ | $$\begin{bmatrix} A \\ B \end{bmatrix}$$|
#
# Ejercicio. Complete la tabla para que las ecuaciones del mismo renglón representen la misma recta que pasa por el origen. Dibuje por cada renglón: la recta, el punto $P$ y los vectores $v$ y $\begin{bmatrix} A \\ B \end{bmatrix}$.
#
# | I Ecuación lineal |  II Ecuación Paramétrica |  III Ecuación vectorial  | IV Otro punto | Ortogonal a |
# |-|-|-|-|-|
# |$2x+3y=0$| | | | |
# | | |$\begin{bmatrix} x \\ y \end{bmatrix} =  t\begin{bmatrix} 2 \\ 1 \end{bmatrix}$| | |
# | | | | $\begin{bmatrix} 3\\ 1 \end{bmatrix}$| |
# | | | | | $\begin{bmatrix} 3\\ 1 \end{bmatrix}$ |

# %% [markdown]
# ## Planos en 3D
#
#
# En la siguiente tabla, las columnas describen algunas representaciones de los planos en 3D. Los últimos renglones presentan como pasar de una representación a otra.
#
#
#
# | | I Ecuación lineal |  II Ecuación Paramétrica |  III Ecuación vectorial  | IV Tres puntos no col. | V Punto y ort.|
# |-|-|-|
# | | $Ax + By + Cz = D$     | $$\begin{matrix} x=P_x + s u_ x + t v_x \\ y=p_y + s u_y + t v_y \\ z=p_z + s u_z + t v_z \end{matrix} $$ | $$\begin{bmatrix} x \\ y \\ z \end{bmatrix} = \begin{bmatrix} P_x \\ P_y \\ P_z \end{bmatrix} + s\begin{bmatrix} u_x \\ u_y \\ u_z \end{bmatrix} + t\begin{bmatrix} v_x \\ v_y \\ v_z \end{bmatrix}$$         | $$P,Q, R$$ | $$\left(\begin{bmatrix} x \\ y \\ z \end{bmatrix} - \begin{bmatrix} P_x \\ P_y \\ P_z \end{bmatrix} \right) \cdot \begin{bmatrix} A \\ B \\ C \end{bmatrix} = 0$$ |
# | De I | | Solución general de $\begin{bmatrix} A & B & C & : & D \end{bmatrix}$ | Solución general de $\begin{bmatrix} A & B & C & : & D \end{bmatrix}$ | | |
# | De II o III || Notación | Notación |  $ \begin{matrix}P = \begin{bmatrix} P_x \\ P_y \\ P_z \end{bmatrix}\\Q = \begin{bmatrix} P_x \\ P_y \\ P_z \end{bmatrix} + 1\begin{bmatrix} v_x \\ v_y  \\v_z \end{bmatrix} \\ R = \begin{bmatrix} P_x \\ P_y \\ P_z \end{bmatrix} + 1\begin{bmatrix} u_x \\ u_y  \\ u_z \end{bmatrix}\end{matrix}$| $$\begin{bmatrix} A \\ B \\ C \end{bmatrix}=\begin{bmatrix} u_x \\ u_y \\ u_z \end{bmatrix}  \times \begin{bmatrix} v_x \\ v_y \\ v_z \end{bmatrix} $$|
# | De IV | | | $\begin{bmatrix} P_x \\ P_y \\ P_z \end{bmatrix}=P$, $\begin{bmatrix} v_x \\ v_y \\ v_z \end{bmatrix}=Q-P$, $\begin{bmatrix} u_x \\ u_y \\ u_z \end{bmatrix}=R-P$ | .| .|
# | De V | Realizar operaciones | | | | .|
# Ejercicio. Complete la tabla para que las ecuaciones del mismo renglón representen el mismo plano. Dibuje por cada renglón:  los puntos $P$, $Q$ y $R$ y los vectores $v$, $u$ y $\begin{bmatrix} A \\ B \\ C\end{bmatrix}$.
#
#
# | I Ecuación lineal |  II Ecuación Paramétrica |  III Ecuación vectorial  | IV Tres puntos | V Punto y ort.|
# |-|-|-|-|-|
# |$2x+3y+z=6$| | | | |
# | | |$\begin{bmatrix} x \\ y \\ z \end{bmatrix} = \begin{bmatrix} -3 \\ 1 \\ 4 \end{bmatrix} + t\begin{bmatrix} 2 \\ 1 \\ -3 \end{bmatrix} + s\begin{bmatrix} 1 \\ 0 \\ 1 \end{bmatrix}$| | |
# | | | | $\begin{bmatrix} 1\\ 2 \\3 \end{bmatrix}$, $\begin{bmatrix} 2\\ 2 \\1 \end{bmatrix}$ y $\begin{bmatrix} -1 \\ 1 \\2 \end{bmatrix}$| .|
# | | | | | $$\left(\begin{bmatrix} x \\ y \\ z \end{bmatrix} - \begin{bmatrix} 4 \\ 1 \\ -3 \end{bmatrix} \right) \cdot \begin{bmatrix} 1 \\ 2 \\ 3 \end{bmatrix} = 0$$|
# La siguiente tabla describe las representaciones de los planos que pasan por el origen.
#
#
#
#  |  Ecuación lineal |   Ecuación Paramétrica |   Ecuación vectorial |  Dos puntos | Ortogonal a
# |-|-|-|
#  | $$Ax + By + Cz = 0$$     | $$\begin{matrix} x=s u_x + t v_x  \\ y=s u_y + t v_y \\ z=s u_z + t v_z \end{matrix} $$ | $$\begin{bmatrix} x \\ y \\ z \end{bmatrix} =  s\begin{bmatrix} u_x \\ u_y \\ u_z \end{bmatrix}+ t\begin{bmatrix} v_x \\ v_y \\ v_z \end{bmatrix}$$         | $\begin{bmatrix} u_x \\ u_y \\ u_z \end{bmatrix}$ y  $\begin{bmatrix} v_x \\ v_y \\ v_y \end{bmatrix}$ | $$\begin{bmatrix} A \\ B \\ C \end{bmatrix}$$|
#
# Ejercicio. Complete la tabla para que las ecuaciones del mismo renglón representen el mismo plano que pasa por el origen.  Dibuje por cada renglón:  los puntos $P$ y $Q$ y los vectores $v$, $u$ y $\begin{bmatrix} A \\ B \\ C\end{bmatrix}$.
#
#
# | I Ecuación lineal |  II Ecuación Paramétrica |  III Ecuación vectorial  | IV Dos puntos | Ortogonal a |
# |-|-|-|-|-|
# |$2x+3y+z=0$| | | | |
# | | |$\begin{bmatrix} x \\ y \\ z \end{bmatrix} =  t\begin{bmatrix} 2 \\ 1 \\ -3 \end{bmatrix} + s\begin{bmatrix} 1 \\ 0 \\ 1 \end{bmatrix}$| | |
# | | | | $\begin{bmatrix} 1\\ 0 \\ -2\end{bmatrix}$ y $\begin{bmatrix} -2\\ -1 \\ -1
# \end{bmatrix}$| |
# | | | | | $\begin{bmatrix}1\\ 2\\ 3 \end{bmatrix}$ |

# %% [markdown]
# ## Rectas en 3D
#
#
# En la siguiente tabla, las columnas describen algunas representaciones de las rectas en 3D. Los últimos renglones presentan como pasar de una representación a otra.
#
#
#
# | | I Ecuaciones lineales |  II Ecuación Paramétrica |  III Ecuación vectorial  | IV Dos puntos | V Ec. simétricas |
# |-|-|-|
# | | $$A_0x + B_0y + C_0z = D_0$$ $$A_1x + B_1y + C_1z = D_1$$     | $$\begin{matrix} x=P_x  + t v_x \\ y=p_y + t v_y \\ z=p_z + t v_z \end{matrix} $$ | $$\begin{bmatrix} x \\ y \\ z \end{bmatrix} = \begin{bmatrix} P_x \\ P_y \\ P_z \end{bmatrix} + t\begin{bmatrix} v_x \\ v_y \\ v_z \end{bmatrix}$$         | $$P,Q$$ | $$
# \frac{x-P_x}{v_x}=\frac{y-P_y}{v_y}=\frac{z-P_z}{v_z}$$ |
# | De I | | Solución general de $\begin{bmatrix} A_0 & B_0 & C_0 & : & D_0\\ A_1 & B_1 & C_1 & : & D_1 \end{bmatrix}$ | Solución general de $\begin{bmatrix} A_0 & B_0 & C_0 & : & D_0\\ A_1 & B_1 & C_1 & : & D_1 \end{bmatrix}$ | | |
# | De II o III || Notación | Notación |  $ \begin{matrix}P = \begin{bmatrix} P_x \\ P_y \\ P_z \end{bmatrix}\\Q = \begin{bmatrix} P_x \\ P_y \\ P_z \end{bmatrix} + 1\begin{bmatrix} v_x \\ v_y  \\v_z \end{bmatrix} \end{matrix}$| Despejar $t$ e igualar, si se puede |
# | De IV | | | $\begin{bmatrix} P_x \\ P_y \\ P_z \end{bmatrix}=P$, $\begin{bmatrix} v_x \\ v_y \\ v_z \end{bmatrix}=Q-P$| .| .|
# | De V | Para cada una de las dos igualdades escribir la ecuación lineal | $$\begin{matrix} x=P_x  + t v_x \\ y=p_y + t v_y \\ z=p_z + t v_z \end{matrix} $$ | $$\begin{bmatrix} x \\ y \\ z \end{bmatrix} = \begin{bmatrix} P_x \\ P_y \\ P_z \end{bmatrix} + t\begin{bmatrix} v_x \\ v_y \\ v_z \end{bmatrix}$$         | | .|
#
# Ejercicio. Complete la tabla para que las ecuaciones del mismo renglón representen la misma recta. Dibuje por cada renglón:  los puntos $P$ y $Q$ y los vectores $v$, $\begin{bmatrix} A_0 \\ B_0 \\ C_0\end{bmatrix}$ y $\begin{bmatrix} A_1 \\ B_1 \\ C_1\end{bmatrix}$.
#
#
# | I Ecuación lineal |  II Ecuación Paramétrica |  III Ecuación vectorial  | IV Dos puntos | V Ec. simétricas |
# |-|-|-|-|-|
# |$$2x+3y+z=6$$ $$3x-1y+2z=2$$| | | | |
# | | |$\begin{bmatrix} x \\ y \\ z \end{bmatrix} = \begin{bmatrix} -3 \\ 1 \\ 4 \end{bmatrix} + t\begin{bmatrix} 2 \\ 1 \\ -3 \end{bmatrix}$ | | |
# | | | | $\begin{bmatrix} 1\\ 2 \\3 \end{bmatrix}$ y $\begin{bmatrix} -1 \\ 1 \\2 \end{bmatrix}$| .|
# | | | | | $$
# \frac{x-1}{2}=\frac{y-3}{3}=\frac{z-1}{2}$$|
#
# La siguiente tabla describe las representaciones de las rectas que pasan por el origen.
#
#
#
#  |  Ecuación lineal |   Ecuación Paramétrica |   Ecuación vectorial |  Otro punto | Ortogonal a
# |-|-|-|
#  | $$A_0x + B_0y + C_0z = 0$$ $$A_1x + B_1y + C_1z = 0$$    | $$\begin{matrix} x= t v_x  \\ y= t v_y \\ z= t v_z \end{matrix} $$ | $$\begin{bmatrix} x \\ y \\ z \end{bmatrix} =   t\begin{bmatrix} v_x \\ v_y \\ v_z \end{bmatrix}$$         |   $\begin{bmatrix} v_x \\ v_y \\ v_y \end{bmatrix}$ | $$\begin{bmatrix} A_0 \\ B_0 \\ C_0 \end{bmatrix}$$ y $$\begin{bmatrix} A_1 \\ B_1 \\ C_1 \end{bmatrix}$$|
#
# Ejercicio. Complete la tabla para que las ecuaciones del mismo renglón representen la misma recta que pasa por el origen.  Dibuje por cada renglón:  el punto $Q$ y los vectores $v$, $\begin{bmatrix} A_0 \\ B_0 \\ C_0\end{bmatrix}$ y $\begin{bmatrix} A_1 \\ B_1 \\ C_1\end{bmatrix}$.
#
# | I Ecuación lineal |  II Ecuación Paramétrica |  III Ecuación vectorial  | IV Dos puntos | V Ec. simétricas |
# |-|-|-|-|-|
# |$$2x+3y+z=0$$ $$3x-1y+2z=0$$| | | | |
# | | |$\begin{bmatrix} x \\ y \\ z \end{bmatrix} = t\begin{bmatrix} 2 \\ 1 \\ -3 \end{bmatrix}$ | | |
# | | | | $\begin{bmatrix} -2 \\ -1 \\-1 \end{bmatrix}$| .|
# | | | | | $$
# \frac{x}{2}=\frac{y}{3}=\frac{z}{2}$$|

# %% [markdown]
# # References
